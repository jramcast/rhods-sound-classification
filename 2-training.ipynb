# %% [markdown]
# # Training
#
# First, import the required libraries for this notebook.

# %%
import os
from pathlib import Path

import boto3
import librosa
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn.metrics import classification_report

# %% [markdown]
# Load the *ESC-10* dataset.

# %%
esc50 = pd.read_csv("data/ESC-50-master/meta/esc50.csv")
esc10 = esc50[esc50.esc10].reset_index(drop=True)
esc10.head()
# Out:
#             filename  fold  target        category  esc10  src_file take
# 0   1-100032-A-0.wav     1       0             dog   True    100032    A
# 1   1-110389-A-0.wav     1       0             dog   True    110389    A
# 2  1-116765-A-41.wav     1      41        chainsaw   True    116765    A
# 3   1-17150-A-12.wav     1      12  crackling_fire   True     17150    A
# 4  1-172649-A-40.wav     1      40      helicopter   True    172649    A

# %% [markdown]
# ## Prepare the Input

# %% [markdown]
# Modify the dataframe to contain the full relative path to each audio file.

# %%
def filename_to_relative_path(filename: str):
    return str(Path("data/ESC-50-master/audio", filename))

paths = esc10.filename.apply(filename_to_relative_path)
data_without_signals = esc10.assign(filename=paths)

data_without_signals.head()
# Out:
#                                      filename  fold  target        category  \
# 0   data/ESC-50-master/audio/1-100032-A-0.wav     1       0             dog
# 1   data/ESC-50-master/audio/1-110389-A-0.wav     1       0             dog
# 2  data/ESC-50-master/audio/1-116765-A-41.wav     1      41        chainsaw
# 3   data/ESC-50-master/audio/1-17150-A-12.wav     1      12  crackling_fire
# 4  data/ESC-50-master/audio/1-172649-A-40.wav     1      40      helicopter
#
#    esc10  src_file take
# 0   True    100032    A
# 1   True    110389    A
# 2   True    116765    A
# 3   True     17150    A
# 4   True    172649    A

# %% [markdown]
# Preprocess each audio file.
# Convert the original signal into a MEL spectrogram.
#
# The MEL spectrogram is 2-dimensional: `(mels, time)`.
# The time dimension depends on the lenght of each sample.
# To easily deal with audio samples of different durations, calculate the mean value of each MEL accross the time axis.
# The input for the model will be an array of 128 MELs.
#
#
# This process will take several seconds.
#
# ```{note}
# Typically, you should perform preprocessing only once and store the results.
# ```

# %%
def wav_to_mels(signal, sample_rate):
    """
    Takes a wav signal and produces the MEL spectrogram data, required by the model as input
    """
    mels = np.mean(
        librosa.feature.melspectrogram(y = signal, sr = sample_rate, n_mels=128), 
        axis=1
    )
    return mels


def file_to_mels(filename: str):
    signal, sr = librosa.load(filename)
    return wav_to_mels(signal, sr)


signals = data_without_signals.filename.apply(file_to_mels)
data = data_without_signals.assign(signal=signals)
data.head()
# Out:
#                                      filename  fold  target        category  \
# 0   data/ESC-50-master/audio/1-100032-A-0.wav     1       0             dog
# 1   data/ESC-50-master/audio/1-110389-A-0.wav     1       0             dog
# 2  data/ESC-50-master/audio/1-116765-A-41.wav     1      41        chainsaw
# 3   data/ESC-50-master/audio/1-17150-A-12.wav     1      12  crackling_fire
# 4  data/ESC-50-master/audio/1-172649-A-40.wav     1      40      helicopter
#
#    esc10  src_file take                                             signal
# 0   True    100032    A  [1.8513412e-06, 1.125981e-05, 1.77284e-05, 3.1...
# 1   True    110389    A  [0.13045727, 0.0018769688, 0.0002673243, 0.001...
# 2   True    116765    A  [0.005726964, 0.027042735, 0.3444246, 4.481706...
# 3   True     17150    A  [5.335389, 2.6672785, 0.7507066, 0.56450623, 0...
# 4   True    172649    A  [49.48378, 37.91428, 40.788185, 70.7473, 90.09...

# %% [markdown]
# The `signal` values are arrays of length 128.
# These values will be the input of the model.

# %% [markdown]
# ## Prepare the Output
#
# The output value of the model should be the probabilty of each class, given a particular input.
# Machine learning models treat categorical outputs as numbers, so you must map each category (or class) to a number.
#
# Add the `category_id` column to the dataframe.
# This column maps classes in the `category` column to numerical indexes.

# %%
classes = list(data.category.unique())
class_ids = {c: idx for idx, c in enumerate(classes)}
class_ids_column = data.category.apply(lambda category: class_ids[category])
data = data.assign(category_id=class_ids_column)
data
# Out:
#                                        filename  fold  target        category  \
# 0     data/ESC-50-master/audio/1-100032-A-0.wav     1       0             dog
# 1     data/ESC-50-master/audio/1-110389-A-0.wav     1       0             dog
# 2    data/ESC-50-master/audio/1-116765-A-41.wav     1      41        chainsaw
# 3     data/ESC-50-master/audio/1-17150-A-12.wav     1      12  crackling_fire
# 4    data/ESC-50-master/audio/1-172649-A-40.wav     1      40      helicopter
# ..                                          ...   ...     ...             ...
# 395   data/ESC-50-master/audio/5-233160-A-1.wav     5       1         rooster
# 396   data/ESC-50-master/audio/5-234879-A-1.wav     5       1         rooster
# 397   data/ESC-50-master/audio/5-234879-B-1.wav     5       1         rooster
# 398  data/ESC-50-master/audio/5-235671-A-38.wav     5      38      clock_tick
# 399     data/ESC-50-master/audio/5-9032-A-0.wav     5       0             dog
#
#      esc10  src_file take                                             signal  \
# 0     True    100032    A  [1.8513412e-06, 1.125981e-05, 1.77284e-05, 3.1...
# 1     True    110389    A  [0.13045727, 0.0018769688, 0.0002673243, 0.001...
# 2     True    116765    A  [0.005726964, 0.027042735, 0.3444246, 4.481706...
# 3     True     17150    A  [5.335389, 2.6672785, 0.7507066, 0.56450623, 0...
# 4     True    172649    A  [49.48378, 37.91428, 40.788185, 70.7473, 90.09...
# ..     ...       ...  ...                                                ...
# 395   True    233160    A  [6.2960116e-06, 6.199518e-05, 0.0006980941, 0....
# 396   True    234879    A  [0.0020287747, 0.0066939634, 0.024266712, 0.03...
# 397   True    234879    B  [0.007926809, 0.025507677, 0.034778807, 0.0476...
# 398   True    235671    A  [9.167025, 1.9049535, 0.17857115, 0.045147046,...
# 399   True      9032    A  [0.0019298552, 0.00024447407, 0.00013779498, 0...
#
#      category_id
# 0              0
# 1              0
# 2              1
# 3              2
# 4              3
# ..           ...
# 395            8
# 396            8
# 397            8
# 398            6
# 399            0
#
# [400 rows x 9 columns]

# %% [markdown]
# ## Create the Training and Validation Subsets
#
# Split the data intro training and validation subsets.
#
# * Folds 1 to 4 for training
# * Fold 5 for validation
#
# Tipically, in machine learning projects, the data is split into three subsets: training, validation, and test.
# The test subset is used to ensure that the final model is not biased towards the validation subset.
#
# Given the small amount of data used in this demo, you ony use the training and validation subsets.

# %%
training_data = data[data.fold < 5]
print("Number of clips: ", training_data.shape[0])
# Out:
# Number of clips:  320

# %%
validation_data = data[data.fold == 5]
validation_data = validation_data.reset_index(drop=True)

print("Number of clips: ", validation_data.shape[0])
# Out:
# Number of clips:  80

# %% [markdown]
# Extract the columns that the model requires for training and validation

# %%
X_train, y_train = training_data.signal, training_data.category_id
X_validation, y_validation = validation_data.signal, validation_data.category_id

# %% [markdown]
# Define the data training and validation loaders required by PyTorch to feed data into the model.

# %%
class Esc10(Dataset):

    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, index):
        return self.X[index], self.y[index]


training_data = Esc10(X_train, y_train)
validation_data = Esc10(X_validation, y_validation)

# Provide training data in batches of 20
train_dataloader = DataLoader(
    training_data, batch_size=20, shuffle=True
)

# Provide a single batches of validation data (80 samples)
validation_dataloader = DataLoader(
    validation_data, batch_size=len(validation_data)
)

# %% [markdown]
# ## Train the Model

# %% [markdown]
# Create the model class.
# The following class defines a feedforward neural network with three layers.
#
# The input size of the first layer must equal the size of the input data.
# In this case, the expected input is an array of 128 elements.
#
# The output layer must return an array of length `NUM_CLASSES`, which is eight in this case.
# The array contains the probabilities of each class.
# For example, `output[0]` contains the probabilty of category id `0`, which maps to the `dog` class.

# %%
NUM_CLASSES = len(classes)


class MyNet(nn.Module):

    def __init__(self):
        super().__init__()
        self.input_layer = nn.Linear(128, 64)
        self.hidden_layer = nn.Linear(64, 16)
        self.output_layer = nn.Linear(16, NUM_CLASSES)

    def forward(self, x):
        x = F.relu(self.input_layer(x))
        x = F.relu(self.hidden_layer(x))
        x = self.output_layer(x)
        return x

# %% [markdown]
# Create functions for training and evaluating the model

# %%
def train(model: nn.Module, epochs: int):

    # Loss and Optimizer functions
    # CrossEntropyLoss run softmax for you in the output
    # Sofmax is required for multi-class classifaction, where the output 
    # probabilities of predicted classes must add up to 1.
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    for epoch in range(epochs):
        running_loss = 0.0
        for i, data in enumerate(train_dataloader, 0):
            # Each iteration gets a batch of data.
            # Each batch contains:
            # [
            #   [clip_1_signal, clip_2_signal, ..., clip_20_signal],
            #   [clip_1_category_id, clip2_category_id, ..., clip_20_category_id],
            # ]
            signals, category_ids = data

            # Set training gradients to zero
            # to avoid tracking info from previous batches
            optimizer.zero_grad()

            # Pass input through the network
            outputs = model(signals)
            # Calculate loss function
            loss = criterion(outputs, category_ids)
            # Gradient descent
            loss.backward()
            optimizer.step()

            # Print statistics every 10 batches
            running_loss += loss.item()
            if i % 10 == 9:
                print(
                    f"[Epoch {epoch + 1}, Batch {i + 1:5d}]"
                    f"training loss: {running_loss / 10:.3f}"
                )
                running_loss = 0.0


def evaluate(model: nn.Module):
    # Inference-only: disable gradient calculation
    with torch.no_grad():
        signals, category_ids = next(iter(validation_dataloader))

        outputs = model(signals)

        _, predictions = torch.max(outputs.data, 1)

        report = classification_report(
            y_validation,
            predictions,
            target_names=classes
        )
        print(report)

# %% [markdown]
# Create and train the model

# %%
model = MyNet()

train(model, epochs=200)
print("Finished Training")
# Out:
# [Epoch 1, Batch    10]training loss: 2.490
# [Epoch 2, Batch    10]training loss: 2.093
# [Epoch 3, Batch    10]training loss: 1.899
# [Epoch 4, Batch    10]training loss: 1.844
# [Epoch 5, Batch    10]training loss: 1.690
# [Epoch 6, Batch    10]training loss: 1.703
# [Epoch 7, Batch    10]training loss: 1.664
# [Epoch 8, Batch    10]training loss: 1.619
# [Epoch 9, Batch    10]training loss: 1.695
# [Epoch 10, Batch    10]training loss: 1.595
# [Epoch 11, Batch    10]training loss: 1.545
# [Epoch 12, Batch    10]training loss: 1.524
# [Epoch 13, Batch    10]training loss: 1.459
# [Epoch 14, Batch    10]training loss: 1.398
# [Epoch 15, Batch    10]training loss: 1.465
# [Epoch 16, Batch    10]training loss: 1.370
# [Epoch 17, Batch    10]training loss: 1.452
# [Epoch 18, Batch    10]training loss: 1.363
# [Epoch 19, Batch    10]training loss: 1.372
# [Epoch 20, Batch    10]training loss: 1.291
# [Epoch 21, Batch    10]training loss: 1.277
# [Epoch 22, Batch    10]training loss: 1.291
# [Epoch 23, Batch    10]training loss: 1.205
# [Epoch 24, Batch    10]training loss: 1.271
# [Epoch 25, Batch    10]training loss: 1.215
# [Epoch 26, Batch    10]training loss: 1.259
# [Epoch 27, Batch    10]training loss: 1.117
# [Epoch 28, Batch    10]training loss: 1.221
# [Epoch 29, Batch    10]training loss: 1.185
# [Epoch 30, Batch    10]training loss: 1.135
# [Epoch 31, Batch    10]training loss: 1.146
# [Epoch 32, Batch    10]training loss: 1.087
# [Epoch 33, Batch    10]training loss: 1.123
# [Epoch 34, Batch    10]training loss: 1.096
# [Epoch 35, Batch    10]training loss: 1.133
# [Epoch 36, Batch    10]training loss: 1.087
# [Epoch 37, Batch    10]training loss: 1.069
# [Epoch 38, Batch    10]training loss: 1.006
# [Epoch 39, Batch    10]training loss: 1.012
# [Epoch 40, Batch    10]training loss: 0.949
# [Epoch 41, Batch    10]training loss: 0.971
# [Epoch 42, Batch    10]training loss: 1.069
# [Epoch 43, Batch    10]training loss: 0.953
# [Epoch 44, Batch    10]training loss: 0.998
# [Epoch 45, Batch    10]training loss: 0.973
# [Epoch 46, Batch    10]training loss: 0.923
# [Epoch 47, Batch    10]training loss: 0.921
# [Epoch 48, Batch    10]training loss: 0.901
# [Epoch 49, Batch    10]training loss: 1.030
# [Epoch 50, Batch    10]training loss: 0.936
# [Epoch 51, Batch    10]training loss: 0.974
# [Epoch 52, Batch    10]training loss: 0.831
# [Epoch 53, Batch    10]training loss: 0.818
# [Epoch 54, Batch    10]training loss: 0.899
# [Epoch 55, Batch    10]training loss: 0.921
# [Epoch 56, Batch    10]training loss: 0.835
# [Epoch 57, Batch    10]training loss: 0.929
# [Epoch 58, Batch    10]training loss: 0.912
# [Epoch 59, Batch    10]training loss: 0.841
# [Epoch 60, Batch    10]training loss: 0.848
# [Epoch 61, Batch    10]training loss: 0.812
# [Epoch 62, Batch    10]training loss: 0.868
# [Epoch 63, Batch    10]training loss: 0.829
# [Epoch 64, Batch    10]training loss: 0.810
# [Epoch 65, Batch    10]training loss: 0.780
# [Epoch 66, Batch    10]training loss: 0.845
# [Epoch 67, Batch    10]training loss: 0.791
# [Epoch 68, Batch    10]training loss: 0.770
# [Epoch 69, Batch    10]training loss: 0.774
# [Epoch 70, Batch    10]training loss: 0.797
# [Epoch 71, Batch    10]training loss: 0.793
# [Epoch 72, Batch    10]training loss: 0.746
# [Epoch 73, Batch    10]training loss: 0.759
# [Epoch 74, Batch    10]training loss: 0.785
# [Epoch 75, Batch    10]training loss: 0.793
# [Epoch 76, Batch    10]training loss: 0.688
# [Epoch 77, Batch    10]training loss: 0.760
# [Epoch 78, Batch    10]training loss: 0.716
# [Epoch 79, Batch    10]training loss: 0.629
# [Epoch 80, Batch    10]training loss: 0.708
# [Epoch 81, Batch    10]training loss: 0.680
# [Epoch 82, Batch    10]training loss: 0.689
# [Epoch 83, Batch    10]training loss: 0.654
# [Epoch 84, Batch    10]training loss: 0.763
# [Epoch 85, Batch    10]training loss: 0.687
# [Epoch 86, Batch    10]training loss: 0.687
# [Epoch 87, Batch    10]training loss: 0.650
# [Epoch 88, Batch    10]training loss: 0.674
# [Epoch 89, Batch    10]training loss: 0.627
# [Epoch 90, Batch    10]training loss: 0.677
# [Epoch 91, Batch    10]training loss: 0.619
# [Epoch 92, Batch    10]training loss: 0.655
# [Epoch 93, Batch    10]training loss: 0.638
# [Epoch 94, Batch    10]training loss: 0.664
# [Epoch 95, Batch    10]training loss: 0.625
# [Epoch 96, Batch    10]training loss: 0.625
# [Epoch 97, Batch    10]training loss: 0.624
# [Epoch 98, Batch    10]training loss: 0.625
# [Epoch 99, Batch    10]training loss: 0.608
# [Epoch 100, Batch    10]training loss: 0.555
# [Epoch 101, Batch    10]training loss: 0.598
# [Epoch 102, Batch    10]training loss: 0.631
# [Epoch 103, Batch    10]training loss: 0.555
# [Epoch 104, Batch    10]training loss: 0.541
# [Epoch 105, Batch    10]training loss: 0.556
# [Epoch 106, Batch    10]training loss: 0.649
# [Epoch 107, Batch    10]training loss: 0.642
# [Epoch 108, Batch    10]training loss: 0.632
# [Epoch 109, Batch    10]training loss: 0.754
# [Epoch 110, Batch    10]training loss: 0.661
# [Epoch 111, Batch    10]training loss: 0.694
# [Epoch 112, Batch    10]training loss: 0.608
# [Epoch 113, Batch    10]training loss: 0.583
# [Epoch 114, Batch    10]training loss: 0.587
# [Epoch 115, Batch    10]training loss: 0.542
# [Epoch 116, Batch    10]training loss: 0.574
# [Epoch 117, Batch    10]training loss: 0.583
# [Epoch 118, Batch    10]training loss: 0.550
# [Epoch 119, Batch    10]training loss: 0.566
# [Epoch 120, Batch    10]training loss: 0.459
# [Epoch 121, Batch    10]training loss: 0.516
# [Epoch 122, Batch    10]training loss: 0.468
# [Epoch 123, Batch    10]training loss: 0.552
# [Epoch 124, Batch    10]training loss: 0.538
# [Epoch 125, Batch    10]training loss: 0.478
# [Epoch 126, Batch    10]training loss: 0.528
# [Epoch 127, Batch    10]training loss: 0.479
# [Epoch 128, Batch    10]training loss: 0.530
# [Epoch 129, Batch    10]training loss: 0.532
# [Epoch 130, Batch    10]training loss: 0.484
# [Epoch 131, Batch    10]training loss: 0.501
# [Epoch 132, Batch    10]training loss: 0.500
# [Epoch 133, Batch    10]training loss: 0.552
# [Epoch 134, Batch    10]training loss: 0.555
# [Epoch 135, Batch    10]training loss: 0.621
# [Epoch 136, Batch    10]training loss: 0.560
# [Epoch 137, Batch    10]training loss: 0.551
# [Epoch 138, Batch    10]training loss: 0.489
# [Epoch 139, Batch    10]training loss: 0.439
# [Epoch 140, Batch    10]training loss: 0.420
# [Epoch 141, Batch    10]training loss: 0.465
# [Epoch 142, Batch    10]training loss: 0.413
# [Epoch 143, Batch    10]training loss: 0.394
# [Epoch 144, Batch    10]training loss: 0.450
# [Epoch 145, Batch    10]training loss: 0.440
# [Epoch 146, Batch    10]training loss: 0.425
# [Epoch 147, Batch    10]training loss: 0.416
# [Epoch 148, Batch    10]training loss: 0.434
# [Epoch 149, Batch    10]training loss: 0.442
# [Epoch 150, Batch    10]training loss: 0.424
# [Epoch 151, Batch    10]training loss: 0.470
# [Epoch 152, Batch    10]training loss: 0.427
# [Epoch 153, Batch    10]training loss: 0.450
# [Epoch 154, Batch    10]training loss: 0.409
# [Epoch 155, Batch    10]training loss: 0.405
# [Epoch 156, Batch    10]training loss: 0.414
# [Epoch 157, Batch    10]training loss: 0.442
# [Epoch 158, Batch    10]training loss: 0.425
# [Epoch 159, Batch    10]training loss: 0.405
# [Epoch 160, Batch    10]training loss: 0.416
# [Epoch 161, Batch    10]training loss: 0.389
# [Epoch 162, Batch    10]training loss: 0.348
# [Epoch 163, Batch    10]training loss: 0.441
# [Epoch 164, Batch    10]training loss: 0.395
# [Epoch 165, Batch    10]training loss: 0.418
# [Epoch 166, Batch    10]training loss: 0.353
# [Epoch 167, Batch    10]training loss: 0.417
# [Epoch 168, Batch    10]training loss: 0.419
# [Epoch 169, Batch    10]training loss: 0.525
# [Epoch 170, Batch    10]training loss: 0.374
# [Epoch 171, Batch    10]training loss: 0.410
# [Epoch 172, Batch    10]training loss: 0.410
# [Epoch 173, Batch    10]training loss: 0.375
# [Epoch 174, Batch    10]training loss: 0.402
# [Epoch 175, Batch    10]training loss: 0.372
# [Epoch 176, Batch    10]training loss: 0.391
# [Epoch 177, Batch    10]training loss: 0.372
# [Epoch 178, Batch    10]training loss: 0.356
# [Epoch 179, Batch    10]training loss: 0.401
# [Epoch 180, Batch    10]training loss: 0.343
# [Epoch 181, Batch    10]training loss: 0.352
# [Epoch 182, Batch    10]training loss: 0.385
# [Epoch 183, Batch    10]training loss: 0.397
# [Epoch 184, Batch    10]training loss: 0.464
# [Epoch 185, Batch    10]training loss: 0.440
# [Epoch 186, Batch    10]training loss: 0.442
# [Epoch 187, Batch    10]training loss: 0.359
# [Epoch 188, Batch    10]training loss: 0.356
# [Epoch 189, Batch    10]training loss: 0.308
# [Epoch 190, Batch    10]training loss: 0.331
# [Epoch 191, Batch    10]training loss: 0.396
# [Epoch 192, Batch    10]training loss: 0.353
# [Epoch 193, Batch    10]training loss: 0.370
# [Epoch 194, Batch    10]training loss: 0.352
# [Epoch 195, Batch    10]training loss: 0.335
# [Epoch 196, Batch    10]training loss: 0.378
# [Epoch 197, Batch    10]training loss: 0.369
# [Epoch 198, Batch    10]training loss: 0.309
# [Epoch 199, Batch    10]training loss: 0.279
# [Epoch 200, Batch    10]training loss: 0.305
# Finished Training

# %% [markdown]
# Evaluate the model.
# The following report provides multiple metrics: accuracy, precision, recall, and f1-score, by class and aggregated.
#
# Tipically, you should use larger datasets to achieve better evaluation results.

# %%
evaluate(model)
# Out:
#                 precision    recall  f1-score   support
#
#            dog       0.25      0.25      0.25         8
#       chainsaw       0.86      0.75      0.80         8
# crackling_fire       0.36      0.50      0.42         8
#     helicopter       0.25      0.12      0.17         8
#           rain       0.50      0.62      0.56         8
#    crying_baby       0.50      0.38      0.43         8
#     clock_tick       0.64      0.88      0.74         8
#       sneezing       0.60      0.75      0.67         8
#        rooster       0.57      0.50      0.53         8
#      sea_waves       0.83      0.62      0.71         8
#
#       accuracy                           0.54        80
#      macro avg       0.54      0.54      0.53        80
#   weighted avg       0.54      0.54      0.53        80

# %% [markdown]
# ## Export the Model for Serving and Upload
#
# To serve the trained the model with RHODS Model Serving, convert the Pytorch model to ONNX format.
# The ONNX format is a open source format for AI models.

# %%
onnx_filename = "sound_classifier.onnx"
input_names = ["mels"]
output_names = ["output"]
# ONNX to infers the input shape from an example
example_input = torch.randn(1, 128)

torch.onnx.export(model, example_input, onnx_filename, input_names=input_names, output_names=output_names)

# %% [markdown]
# Upload the model to the storage layer.

# %%
key_id = os.getenv("AWS_ACCESS_KEY_ID")
secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")
region = os.getenv("AWS_DEFAULT_REGION")
endpoint = os.getenv("AWS_S3_ENDPOINT")
bucket_name = os.getenv("AWS_S3_BUCKET")

s3_client = boto3.client(
    "s3",
    region,
    aws_access_key_id=key_id,
    aws_secret_access_key=secret_key,
    endpoint_url=endpoint,
    use_ssl=True
)

s3_client.upload_file(onnx_filename, bucket_name, Key=onnx_filename)

print(f"File {onnx_filename} uploaded to S3!")
# Out:
# File sound_classifier.onnx uploaded to S3!
